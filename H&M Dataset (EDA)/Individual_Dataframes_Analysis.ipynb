# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

'''
   Exploratory Data Analysis
   on H & M Dataset
'''

# Ownership
__author__ = ["M. Haseeb Hassan"]
__copyright__ = ["Copyrights @ hacceebhassan"]
__license__ = "MIT"
__version__ = "1.0.1"
__maintainer__ = "M. Haseeb Hassan"
__email__ = "hacceebhassan@gmail.com"
__status__ = "Development"

# %%
# Importing Libraries
from functions.individual_analysis import *

# %%
# data

art = pd.read_csv("data/articles.csv")
cust = pd.read_csv("data/customers.csv")
trans = pd.read_csv("data/transactions_train.csv")

# %% [markdown]
# # Individual Dataframes Analysis

# %% [markdown]
# ## Articles Database Analysis

# %%
# Articles Key Features
articles_key_features(art)

# %%
# Bar Plot Visualization

articles_bar_plots(art, 'index_group_name', pct=True)
sns.set_style("darkgrid", {"axes.facecolor": ".9"})

#plot_bar(art, 'index_name', pct=True)

# %% [markdown]
# Most of the articles are in categories (index) of Ladieswear and Baby/Children. The smallest amount of articles is in Sport group.

# %% [markdown]
# ## Customer Database Analysis

# %%
# Customer Key Features
customers_key_features (cust)

# %%
# Customers Age
customers_age (cust)

# %% [markdown]
# The distribution shows that there are two main age-groups of customers: around 20-30 years old and 45-55 years old. Let's check how old is the oldest customer.

# %% [markdown]
# ## Transactions Database Analysis

# %%
# Transaction Key Features
transactions_key_features(trans)

# %%
# Price Distribution
transactions_distribution (trans)
